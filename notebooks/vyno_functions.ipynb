# %%
import pandas as pd
import numpy as np

# %%
wine_df = pd.read_csv('../data/processed/wine_dataset_all.csv', dtype=str).iloc[: , 1:]

# %%
wine_df = wine_df.drop_duplicates(subset=['description'])

# %%
df = pd.read_csv(
            '../data/processed/wine_dataset_all.csv', dtype=str).dropna(subset=["description"]).drop_duplicates(subset=['description'])
wine_descriptions = df.sample(12)
# wine_df
wine_descriptions
# Out:
#        Unnamed: 0    country  \
# 9781         9781  Argentina
# 66958       66958         US
# 216122      65187         US
# 80388       80388     France
# 207632      56697         US
# 194563      43628   Portugal
# 121418     121418         US
# 9148         9148     France
# 76431       76431         US
# 139283     139283      Chile
# 44103       44103         US
# 73297       73297         US
#
#                                               description  \
# 9781    This overly ripe Malbec is packed with rooty s...
# 66958   It's all in your face in this modern-style Cha...
# 216122  A rich pink color and tangy, concentrated rasp...
# 80388   Light colored and fruity, this is all about re...
# 207632  Subtle aromatics ride a steely frame of straig...
# 194563  Produced from the Espadeiro, a grape widely us...
# 121418  The Andretti style is fruit-driven and easy, a...
# 9148    Earthy notes mix in with fresh Mirabelle plum ...
# 76431   A consistent winner, this single-vineyard Char...
# 139283  Leather, earth and bold fruit on the nose, and...
# 44103   Orange blossoms and toasted brioche tempt on t...
# 73297   A majority Pinot Noir (54%), this brut rosé ha...
#
#                                 wine_name          province  \
# 9781                            Padrillos  Mendoza Province
# 66958       Sangiacomo Vineyard West Rows        California
# 216122               Vintner's Collection        California
# 80388                                 NaN          Burgundy
# 207632                                NaN        California
# 194563    Espadeiro Colheita Seleccionada       Vinho Verde
# 121418                                NaN        California
# 9148                           Collection            Alsace
# 76431   The Big Sissy Conner Lee Vineyard        Washington
# 139283                     Quatro Reserva  Colchagua Valley
# 44103            Reserve Barrel Fermented          New York
# 73297                Brut Rosé Excellence        California
#
#                       region               sub_region               grape  \
# 9781                 Mendoza                      NaN              Malbec
# 66958               Carneros              Napa-Sonoma          Chardonnay
# 216122            California         California Other                Rosé
# 80388      Gevrey-Chambertin                      NaN          Pinot Noir
# 207632  Russian River Valley                   Sonoma          Chardonnay
# 194563                   NaN                      NaN                Rosé
# 121418           Napa Valley                     Napa  Cabernet Sauvignon
# 9148                  Alsace                      NaN         Pinot Blanc
# 76431   Columbia Valley (WA)          Columbia Valley          Chardonnay
# 139283                   NaN                      NaN           Red Blend
# 44103            Cayuga Lake             Finger Lakes          Chardonnay
# 73297       Mendocino County  Mendocino/Lake Counties     Sparkling Blend
#
#                    vineyard                                              title
# 9781           Siesta Wines                                                NaN
# 66958   Signaterra Benziger                                                NaN
# 216122             Sterling  Sterling 2016 Vintner's Collection Rosé (Calif...
# 80388       Joseph Faiveley                                                NaN
# 207632              Bravium     Bravium 2015 Chardonnay (Russian River Valley)
# 194563    Quinta de Gomariz  Quinta de Gomariz 2015 Espadeiro Colheita Sele...
# 121418             Andretti                                                NaN
# 9148    Cave de Ribeauvillé                                                NaN
# 76431                Gorman                                                NaN
# 139283             MontGras                                                NaN
# 44103             Treleaven                                                NaN
# 73297       Scharffenberger                                                NaN

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords

from gensim.models.phrases import Phrases, Phraser

import string

ngrams = Phrases.load('ngrams')
descriptor_map = pd.read_csv('descriptor_mapping.csv').set_index('raw descriptor')

def preprocess_description(description, ngram, descriptor_map, level=3):
    tokens = tokenize_description(description)
    phrase = ngram[tokens]
    descriptors = [map_descriptor(word, descriptor_map, level) for word in phrase]
    descripters_cleaned = [str(desc) for desc in descriptors if desc is not None]
    
    return ' '.join(descripters_cleaned)

def tokenize_description(description):
    stop_words = set(stopwords.words('english'))
    punctuation_table = str.maketrans({key: None for key in string.punctuation})
    stemmer = SnowballStemmer('english')
    
    normalized_description = []
    word_tokens = word_tokenize(description)
    for word in word_tokens:
        lower_case = str.lower(str(word))
        stemmed_word = stemmer.stem(lower_case)
        no_punctuation = stemmed_word.translate(punctuation_table)
        if len(no_punctuation) > 1 and no_punctuation not in stop_words:
            normalized_description.append(no_punctuation)
    
    return normalized_description

def map_descriptor(word, mapping, level=3):
    if word in list(mapping.index):
        return mapping[f'level_{level}'][word]

# %%
test_desc = wine_df['description'][0]
print(test_desc)
# Out:
# This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.

# %%
preprocess_description(test_desc, ngrams, descriptor_map)
# Out:
# 'oak juicy cherry fruit caramel elegant mint'

# %%
import pickle

def load_tf_idf_weights(pkl):
    tf_idf = pickle.load(open(pkl, "rb"))
    return dict(zip(tf_idf.get_feature_names(), tf_idf.idf_))

tfidf_weightings = load_tf_idf_weights("vectorizer.pickle")

# %%
from gensim.models import Word2Vec

def load_model(model):
    return Word2Vec.load(model)

word2vec = load_model("wine_word2vec_model.bin")

# %%
from sklearn.metrics.pairwise import cosine_similarity

def order_12_wines(list_of_descriptors, wine_df, tfidf_weightings):
    weighted_review_terms = []
    for term in list_of_descriptors:
        if term not in tfidf_weightings:
            if term not in descriptor_mapping.index:
                print('choose a different descriptor from', term)
                continue
            else:
                term = descriptor_mapping['normalized'][term]
        tfidf_weighting = tfidf_weightings[term]
        word_vector = word2vec.wv.get_vector(term).reshape(1, 300)
        weighted_word_vector = tfidf_weighting * word_vector
        weighted_review_terms.append(weighted_word_vector)
    descriptors_vector = sum(weighted_review_terms)
    
    wine_review_vectors = []
    for terms in wine_df['normalized_descriptors']:
        terms = terms[2:-2]
        terms = terms.split("""', '""")
        descriptor_count = 0
        weighted_review_terms = []
        for term in terms:
            if term in tfidf_weightings.keys():
                tfidf_weighting = tfidf_weightings[term]
                word_vector = word2vec.wv.get_vector(term).reshape(1, 300)
                weighted_word_vector = tfidf_weighting * word_vector
                weighted_review_terms.append(weighted_word_vector)
                descriptor_count += 1
            else:
                continue
        try:
            review_vector = sum(weighted_review_terms)/len(weighted_review_terms)
        except:
            review_vector = []
        vector_and_count = [terms, review_vector, descriptor_count]
        wine_review_vectors.append(review_vector)
        
    wine_df['review_vector'] = list( wine_review_vectors)
    
    cosine_similarities = []
    for vector in wine_review_vectors:
        print(vector)
        cosine = sklearn.metrics.pairwise.cosine_similarity(descriptors_vector, vector)
        cosine_similarities.append(cosine)
        
    wine_df['cosine_similarities'] = list(cosine_similarities)
    
    return wine_df
    
example_df = pd.read_csv('wine_sample.csv', dtype=str)
descriptors = ['savory', 'rich', 'round', 'shimmer', 'spice', 'blackberry', 'oak', 'fruit']
example_df.head()

order_12_wines(descriptors[:2], example_df, tfidf_weightings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0d49772e0066> in <module>
#      50     return wine_df
#      51
# ---> 52 example_df = pd.read_csv('wine_sample.csv', dtype=str)
#      53 descriptors = ['savory', 'rich', 'round', 'shimmer', 'spice', 'blackberry', 'oak', 'fruit']
#      54 example_df.head()
#
# NameError: name 'pd' is not defined

# %%
example_df
# Out:
#          country                                        description  \
# 0             US  Exuberant in red fruit, this is a softly textu...
# 1             US  Subdued red fruit is kept fresh by moderate ac...
# 2        Austria  Beautifully poised notes of ripe red and black...
# 3       Portugal  Tightly coiled, the firm tannins hold down the...
# 4   South Africa  This wine has an exuberant, juicy quality to i...
# 5          Spain  Solid on the nose, with pure berry aromas matc...
# 6        Austria  Sonorous oak notes in vain seek to calm down t...
# 7   South Africa  Savory aromas of balsamic vinegar paired with ...
# 8      Australia  Smells dry and dusty, like a midwestern countr...
# 9      Australia  From a single vineyard in the Ebenezer region,...
# 10   New Zealand  This is a rather weighty Pinot Noir, still fil...
#
#                wine_name          province            region sub_region  \
# 0       Nance's Vineyard        California  Alexander Valley     Sonoma
# 1       Benchland Series        California       Napa Valley       Napa
# 2     Burggarten Reserve  Niederösterreich               NaN        NaN
# 3   Duas Quintas Reserva             Douro               NaN        NaN
# 4                    NaN      Stellenbosch               NaN        NaN
# 5                Crianza    Northern Spain  Ribera del Duero        NaN
# 6               Kalkofen        Burgenland               NaN        NaN
# 7                    NaN      Western Cape               NaN        NaN
# 8                 Thomas   New South Wales     Hunter Valley        NaN
# 9     Amon-Ra Unfiltered   South Australia    Barossa Valley        NaN
# 10                   NaN     Central Otago               NaN        NaN
#
#              grape             vineyard  \
# 0        Zinfandel           Ousterhout
# 1           Malbec  William Hill Estate
# 2         Zweigelt          R&A; Pfaffl
# 3   Portuguese Red          Ramos-Pinto
# 4            Syrah         Rudi Schultz
# 5   Tinto del Pais          Viña Arnáiz
# 6    Blaufränkisch             Weninger
# 7           Shiraz          Allée Bleue
# 8           Shiraz        Macquariedale
# 9           Shiraz             Glaetzer
# 10      Pinot Noir       Prophet's Rock
#
#                                                 title  \
# 0                                                 NaN
# 1   William Hill Estate 2013 Benchland Series Malb...
# 2   R&A; Pfaffl 2013 Burggarten Reserve Zweigelt (...
# 3   Ramos-Pinto 2004 Duas Quintas Reserva Red (Douro)
# 4              Rudi Schultz 2004 Syrah (Stellenbosch)
# 5                                                 NaN
# 6   Weninger 2013 Kalkofen Blaufränkisch (Burgenland)
# 7                                                 NaN
# 8    Macquariedale 1999 Thomas Shiraz (Hunter Valley)
# 9                                                 NaN
# 10     Prophet's Rock 2007 Pinot Noir (Central Otago)
#
#                                normalized_descriptors  \
# 0   ['exuberant', 'fruit', 'soft', 'complex', 'ber...
# 1   ['fruit', 'fresh', 'full_bodied', 'dense', 'gr...
# 2   ['ripe', 'cherry', 'pepper', 'spice', 'shimmer...
# 3   ['firm', 'exuberant', 'berry', 'fruit', 'fresh...
# 4   ['exuberant', 'juicy', 'bright', 'berry', 'spi...
# 5   ['berry', 'vanilla', 'fresh', 'medium_bodied',...
# 6   ['oak', 'pepper', 'exuberant', 'blueberry', 's...
# 7   ['savory', 'pepper', 'cherry', 'exuberant', 'j...
# 8   ['dry', 'dust', 'fruit', 'bright', 'berry', 'c...
# 9   ['rich', 'blackberry', 'fruit', 'fresh', 'juic...
# 10  ['full_bodied', 'exuberant', 'fruit', 'plum', ...
#
#                                    description_vector descriptor_count
# 0   [[ 0.44267905 -4.394822   -4.396351   -0.08030...               11
# 1   [[ 7.56087363e-01 -5.52146387e+00 -2.48302293e...               13
# 2   [[-1.2163753e-01 -5.8665137e+00 -3.2175047e+00...                9
# 3   [[ 8.3381760e-01 -2.7187488e+00 -2.3070815e+00...               10
# 4   [[ 0.38180396 -3.9987466  -4.896322    0.85400...                9
# 5   [[-1.03987205e+00 -4.75814629e+00 -3.54387379e...               11
# 6   [[ 1.4493425e+00 -5.0995746e+00 -3.5631576e+00...               10
# 7   [[ 9.16855931e-01 -4.30654907e+00 -5.27289248e...                8
# 8   [[ 2.57434011e-01 -5.61576271e+00 -3.47763491e...                9
# 9   [[ 3.62765074e-01 -4.60845900e+00 -3.48230505e...               11
# 10  [[ 1.0496293  -5.30035    -3.4237044   0.18038...                8

# %%
import requests
import json

url = "http://127.0.0.1:8000/12wines"

payload = json.dumps({
  "data": "hello"
})
headers = {
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#   "http://www.w3.org/TR/html4/loose.dtd">
# <html>
#   <head>
#     <title>_pickle.UnpicklingError: could not find MARK // Werkzeug Debugger</title>
#     <link rel="stylesheet" href="?__debugger__=yes&amp;cmd=resource&amp;f=style.css"
#         type="text/css">
#     <!-- We need to make sure this has a favicon so that the debugger does
#          not by accident trigger a request to /favicon.ico which might
#          change the application state. -->
#     <link rel="shortcut icon"
#         href="?__debugger__=yes&amp;cmd=resource&amp;f=console.png">
#     <script src="?__debugger__=yes&amp;cmd=resource&amp;f=jquery.js"></script>
#     <script src="?__debugger__=yes&amp;cmd=resource&amp;f=debugger.js"></script>
#     <script type="text/javascript">
#       var TRACEBACK = 140400599802096,
#           CONSOLE_MODE = false,
#           EVALEX = true,
#           EVALEX_TRUSTED = false,
#           SECRET = "Ax1u8lOw0JXS7v6bDON9";
#     </script>
#   </head>
#   <body style="background-color: #fff">
#     <div class="debugger">
# <h1>_pickle.UnpicklingError</h1>
# <div class="detail">
#   <p class="errormsg">_pickle.UnpicklingError: could not find MARK</p>
# </div>
# <h2 class="traceback">Traceback <em>(most recent call last)</em></h2>
# <div class="traceback">
#
#   <ul><li><div class="frame" id="frame-140400599802040">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py"</cite>,
#       line <em class="line">2309</em>,
#       in <code class="function">__call__</code></h4>
#   <div class="source"><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws">    </span>def __call__(self, environ, start_response):</pre>
# <pre class="line before"><span class="ws">        </span>&quot;&quot;&quot;The WSGI server calls the Flask application object as the</pre>
# <pre class="line before"><span class="ws">        </span>WSGI application. This calls :meth:`wsgi_app` which can be</pre>
# <pre class="line before"><span class="ws">        </span>wrapped to applying middleware.&quot;&quot;&quot;</pre>
# <pre class="line current"><span class="ws">        </span>return self.wsgi_app(environ, start_response)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def __repr__(self):</pre>
# <pre class="line after"><span class="ws">        </span>return '&lt;%s %r&gt;' % (</pre>
# <pre class="line after"><span class="ws">            </span>self.__class__.__name__,</pre>
# <pre class="line after"><span class="ws">            </span>self.name,</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400599801928">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py"</cite>,
#       line <em class="line">2295</em>,
#       in <code class="function">wsgi_app</code></h4>
#   <div class="source"><pre class="line before"><span class="ws">            </span>try:</pre>
# <pre class="line before"><span class="ws">                </span>ctx.push()</pre>
# <pre class="line before"><span class="ws">                </span>response = self.full_dispatch_request()</pre>
# <pre class="line before"><span class="ws">            </span>except Exception as e:</pre>
# <pre class="line before"><span class="ws">                </span>error = e</pre>
# <pre class="line current"><span class="ws">                </span>response = self.handle_exception(e)</pre>
# <pre class="line after"><span class="ws">            </span>except:</pre>
# <pre class="line after"><span class="ws">                </span>error = sys.exc_info()[1]</pre>
# <pre class="line after"><span class="ws">                </span>raise</pre>
# <pre class="line after"><span class="ws">            </span>return response(environ, start_response)</pre>
# <pre class="line after"><span class="ws">        </span>finally:</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400599801984">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py"</cite>,
#       line <em class="line">1741</em>,
#       in <code class="function">handle_exception</code></h4>
#   <div class="source"><pre class="line before"><span class="ws">            </span># if we want to repropagate the exception, we can attempt to</pre>
# <pre class="line before"><span class="ws">            </span># raise it with the whole traceback in case we can do that</pre>
# <pre class="line before"><span class="ws">            </span># (the function was actually called from the except part)</pre>
# <pre class="line before"><span class="ws">            </span># otherwise, we just raise the error again</pre>
# <pre class="line before"><span class="ws">            </span>if exc_value is e:</pre>
# <pre class="line current"><span class="ws">                </span>reraise(exc_type, exc_value, tb)</pre>
# <pre class="line after"><span class="ws">            </span>else:</pre>
# <pre class="line after"><span class="ws">                </span>raise e</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">        </span>self.log_exception((exc_type, exc_value, tb))</pre>
# <pre class="line after"><span class="ws">        </span>if handler is None:</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600063392">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/_compat.py"</cite>,
#       line <em class="line">35</em>,
#       in <code class="function">reraise</code></h4>
#   <div class="source"><pre class="line before"><span class="ws">    </span>from io import StringIO</pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws">    </span>def reraise(tp, value, tb=None):</pre>
# <pre class="line before"><span class="ws">        </span>if value.__traceback__ is not tb:</pre>
# <pre class="line before"><span class="ws">            </span>raise value.with_traceback(tb)</pre>
# <pre class="line current"><span class="ws">        </span>raise value</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>implements_to_string = _identity</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws"></span>else:</pre>
# <pre class="line after"><span class="ws">    </span>text_type = unicode</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600062272">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py"</cite>,
#       line <em class="line">2292</em>,
#       in <code class="function">wsgi_app</code></h4>
#   <div class="source"><pre class="line before"><span class="ws">        </span>ctx = self.request_context(environ)</pre>
# <pre class="line before"><span class="ws">        </span>error = None</pre>
# <pre class="line before"><span class="ws">        </span>try:</pre>
# <pre class="line before"><span class="ws">            </span>try:</pre>
# <pre class="line before"><span class="ws">                </span>ctx.push()</pre>
# <pre class="line current"><span class="ws">                </span>response = self.full_dispatch_request()</pre>
# <pre class="line after"><span class="ws">            </span>except Exception as e:</pre>
# <pre class="line after"><span class="ws">                </span>error = e</pre>
# <pre class="line after"><span class="ws">                </span>response = self.handle_exception(e)</pre>
# <pre class="line after"><span class="ws">            </span>except:</pre>
# <pre class="line after"><span class="ws">                </span>error = sys.exc_info()[1]</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600063280">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py"</cite>,
#       line <em class="line">1815</em>,
#       in <code class="function">full_dispatch_request</code></h4>
#   <div class="source"><pre class="line before"><span class="ws">            </span>request_started.send(self)</pre>
# <pre class="line before"><span class="ws">            </span>rv = self.preprocess_request()</pre>
# <pre class="line before"><span class="ws">            </span>if rv is None:</pre>
# <pre class="line before"><span class="ws">                </span>rv = self.dispatch_request()</pre>
# <pre class="line before"><span class="ws">        </span>except Exception as e:</pre>
# <pre class="line current"><span class="ws">            </span>rv = self.handle_user_exception(e)</pre>
# <pre class="line after"><span class="ws">        </span>return self.finalize_request(rv)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def finalize_request(self, rv, from_error_handler=False):</pre>
# <pre class="line after"><span class="ws">        </span>&quot;&quot;&quot;Given the return value from a view function this finalizes</pre>
# <pre class="line after"><span class="ws">        </span>the request by converting it into a response and invoking the</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600063616">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py"</cite>,
#       line <em class="line">1718</em>,
#       in <code class="function">handle_user_exception</code></h4>
#   <div class="source"><pre class="line before"><span class="ws">            </span>return self.handle_http_exception(e)</pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws">        </span>handler = self._find_error_handler(e)</pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws">        </span>if handler is None:</pre>
# <pre class="line current"><span class="ws">            </span>reraise(exc_type, exc_value, tb)</pre>
# <pre class="line after"><span class="ws">        </span>return handler(e)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def handle_exception(self, e):</pre>
# <pre class="line after"><span class="ws">        </span>&quot;&quot;&quot;Default exception handling that kicks in when an exception</pre>
# <pre class="line after"><span class="ws">        </span>occurs that is not caught.  In debug mode the exception will</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600063784">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/_compat.py"</cite>,
#       line <em class="line">35</em>,
#       in <code class="function">reraise</code></h4>
#   <div class="source"><pre class="line before"><span class="ws">    </span>from io import StringIO</pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws">    </span>def reraise(tp, value, tb=None):</pre>
# <pre class="line before"><span class="ws">        </span>if value.__traceback__ is not tb:</pre>
# <pre class="line before"><span class="ws">            </span>raise value.with_traceback(tb)</pre>
# <pre class="line current"><span class="ws">        </span>raise value</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>implements_to_string = _identity</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws"></span>else:</pre>
# <pre class="line after"><span class="ws">    </span>text_type = unicode</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600063336">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py"</cite>,
#       line <em class="line">1813</em>,
#       in <code class="function">full_dispatch_request</code></h4>
#   <div class="source"><pre class="line before"><span class="ws">        </span>self.try_trigger_before_first_request_functions()</pre>
# <pre class="line before"><span class="ws">        </span>try:</pre>
# <pre class="line before"><span class="ws">            </span>request_started.send(self)</pre>
# <pre class="line before"><span class="ws">            </span>rv = self.preprocess_request()</pre>
# <pre class="line before"><span class="ws">            </span>if rv is None:</pre>
# <pre class="line current"><span class="ws">                </span>rv = self.dispatch_request()</pre>
# <pre class="line after"><span class="ws">        </span>except Exception as e:</pre>
# <pre class="line after"><span class="ws">            </span>rv = self.handle_user_exception(e)</pre>
# <pre class="line after"><span class="ws">        </span>return self.finalize_request(rv)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def finalize_request(self, rv, from_error_handler=False):</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600063840">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py"</cite>,
#       line <em class="line">1799</em>,
#       in <code class="function">dispatch_request</code></h4>
#   <div class="source"><pre class="line before"><span class="ws">        </span># request came with the OPTIONS method, reply automatically</pre>
# <pre class="line before"><span class="ws">        </span>if getattr(rule, 'provide_automatic_options', False) \</pre>
# <pre class="line before"><span class="ws">           </span>and req.method == 'OPTIONS':</pre>
# <pre class="line before"><span class="ws">            </span>return self.make_default_options_response()</pre>
# <pre class="line before"><span class="ws">        </span># otherwise dispatch to the handler for that endpoint</pre>
# <pre class="line current"><span class="ws">        </span>return self.view_functions[rule.endpoint](**req.view_args)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def full_dispatch_request(self):</pre>
# <pre class="line after"><span class="ws">        </span>&quot;&quot;&quot;Dispatches the request and on top of that performs request</pre>
# <pre class="line after"><span class="ws">        </span>pre and postprocessing as well as HTTP exception catching and</pre>
# <pre class="line after"><span class="ws">        </span>error handling.</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600063952">
#   <h4>File <cite class="filename">"/home/dilyar/Downloads/opleiding_ki/tweedejaars_project/code/Vyno-Recommendation-Engine/api_call.py"</cite>,
#       line <em class="line">102</em>,
#       in <code class="function">get_descriptors</code></h4>
#   <div class="source"><pre class="line before"><span class="ws">    </span># TEST CODE END</pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws">    </span># wine_descriptions.to_csv('josephbarneswines_test.csv')</pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws">    </span># load models</pre>
# <pre class="line current"><span class="ws">    </span>embeddings = Word2Vec.load('models/wine_word2vec_model.bin')</pre>
# <pre class="line after"><span class="ws">    </span>tfidf_weightings = load_tf_idf_weights()</pre>
# <pre class="line after"><span class="ws">    </span>ngrams = load_ngrams()</pre>
# <pre class="line after"><span class="ws">    </span>descriptor_map = load_descriptor_map()</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span># process descriptions</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600063560">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/word2vec.py"</cite>,
#       line <em class="line">1152</em>,
#       in <code class="function">load</code></h4>
#   <div class="source"><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws">            </span>return model</pre>
# <pre class="line before"><span class="ws">        </span>except AttributeError:</pre>
# <pre class="line before"><span class="ws">            </span>logger.info('Model saved using code from earlier Gensim Version. Re-loading old model in a compatible way.')</pre>
# <pre class="line before"><span class="ws">            </span>from gensim.models.deprecated.word2vec import load_old_word2vec</pre>
# <pre class="line current"><span class="ws">            </span>return load_old_word2vec(*args, **kwargs)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws"></span>class BrownCorpus(object):</pre>
# <pre class="line after"><span class="ws">    </span>&quot;&quot;&quot;Iterate over sentences from the `Brown corpus &lt;https://en.wikipedia.org/wiki/Brown_Corpus&gt;`_</pre>
# <pre class="line after"><span class="ws">     </span>(part of `NLTK data &lt;https://www.nltk.org/data.html&gt;`_).</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600063448">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/deprecated/word2vec.py"</cite>,
#       line <em class="line">169</em>,
#       in <code class="function">load_old_word2vec</code></h4>
#   <div class="source"><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span>MAX_WORDS_IN_BATCH = 10000</pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span>def load_old_word2vec(*args, **kwargs):</pre>
# <pre class="line current"><span class="ws">    </span>old_model = Word2Vec.load(*args, **kwargs)</pre>
# <pre class="line after"><span class="ws">    </span>vector_size = getattr(old_model, 'vector_size', old_model.layer1_size)</pre>
# <pre class="line after"><span class="ws">    </span>params = {</pre>
# <pre class="line after"><span class="ws">        </span>'size': vector_size,</pre>
# <pre class="line after"><span class="ws">        </span>'alpha': old_model.alpha,</pre>
# <pre class="line after"><span class="ws">        </span>'window': old_model.window,</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600063504">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/deprecated/word2vec.py"</cite>,
#       line <em class="line">1617</em>,
#       in <code class="function">load</code></h4>
#   <div class="source"><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws">    </span>save.__doc__ = SaveLoad.save.__doc__</pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws">    </span>@classmethod</pre>
# <pre class="line before"><span class="ws">    </span>def load(cls, *args, **kwargs):</pre>
# <pre class="line current"><span class="ws">        </span>model = super(Word2Vec, cls).load(*args, **kwargs)</pre>
# <pre class="line after"><span class="ws">        </span># update older models</pre>
# <pre class="line after"><span class="ws">        </span>if hasattr(model, 'table'):</pre>
# <pre class="line after"><span class="ws">            </span>delattr(model, 'table')  # discard in favor of cum_table</pre>
# <pre class="line after"><span class="ws">        </span>if model.negative and hasattr(model.wv, 'index2word'):</pre>
# <pre class="line after"><span class="ws">            </span>model.make_cum_table()  # rebuild cum_table from vocabulary</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600062664">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/deprecated/old_saveload.py"</cite>,
#       line <em class="line">87</em>,
#       in <code class="function">load</code></h4>
#   <div class="source"><pre class="line before"><span class="ws">        </span>&quot;&quot;&quot;</pre>
# <pre class="line before"><span class="ws">        </span>logger.info(&quot;loading %s object from %s&quot;, cls.__name__, fname)</pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws">        </span>compress, subname = SaveLoad._adapt_by_suffix(fname)</pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line current"><span class="ws">        </span>obj = unpickle(fname)</pre>
# <pre class="line after"><span class="ws">        </span>obj._load_specials(fname, mmap, compress, subname)</pre>
# <pre class="line after"><span class="ws">        </span>logger.info(&quot;loaded %s&quot;, fname)</pre>
# <pre class="line after"><span class="ws">        </span>return obj</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def _load_specials(self, fname, mmap, compress, subname):</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140400600063728">
#   <h4>File <cite class="filename">"/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/deprecated/old_saveload.py"</cite>,
#       line <em class="line">379</em>,
#       in <code class="function">unpickle</code></h4>
#   <div class="source"><pre class="line before"><span class="ws">        </span>file_bytes = file_bytes.replace(b'gensim.models.doc2vec', b'gensim.models.deprecated.doc2vec')</pre>
# <pre class="line before"><span class="ws">        </span>file_bytes = file_bytes.replace(b'gensim.models.fasttext', b'gensim.models.deprecated.fasttext')</pre>
# <pre class="line before"><span class="ws">        </span>file_bytes = file_bytes.replace(</pre>
# <pre class="line before"><span class="ws">            </span>b'gensim.models.wrappers.fasttext', b'gensim.models.deprecated.fasttext_wrapper')</pre>
# <pre class="line before"><span class="ws">        </span>if sys.version_info &gt; (3, 0):</pre>
# <pre class="line current"><span class="ws">            </span>return _pickle.loads(file_bytes, encoding='latin1')</pre>
# <pre class="line after"><span class="ws">        </span>else:</pre>
# <pre class="line after"><span class="ws">            </span>return _pickle.loads(file_bytes)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws"></span>def pickle(obj, fname, protocol=2):</pre></div>
# </div>
# </ul>
#   <blockquote>_pickle.UnpicklingError: could not find MARK</blockquote>
# </div>
#
# <div class="plain">
#   <form action="/?__debugger__=yes&amp;cmd=paste" method="post">
#     <p>
#       <input type="hidden" name="language" value="pytb">
#       This is the Copy/Paste friendly version of the traceback.  <span
#       class="pastemessage">You can also paste this traceback into
#       a <a href="https://gist.github.com/">gist</a>:
#       <input type="submit" value="create paste"></span>
#     </p>
#     <textarea cols="50" rows="10" name="code" readonly>Traceback (most recent call last):
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py&quot;, line 2309, in __call__
#     return self.wsgi_app(environ, start_response)
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py&quot;, line 2295, in wsgi_app
#     response = self.handle_exception(e)
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py&quot;, line 1741, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/_compat.py&quot;, line 35, in reraise
#     raise value
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py&quot;, line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py&quot;, line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py&quot;, line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/_compat.py&quot;, line 35, in reraise
#     raise value
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py&quot;, line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py&quot;, line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File &quot;/home/dilyar/Downloads/opleiding_ki/tweedejaars_project/code/Vyno-Recommendation-Engine/api_call.py&quot;, line 102, in get_descriptors
#     embeddings = Word2Vec.load('models/wine_word2vec_model.bin')
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/word2vec.py&quot;, line 1152, in load
#     return load_old_word2vec(*args, **kwargs)
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/deprecated/word2vec.py&quot;, line 169, in load_old_word2vec
#     old_model = Word2Vec.load(*args, **kwargs)
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/deprecated/word2vec.py&quot;, line 1617, in load
#     model = super(Word2Vec, cls).load(*args, **kwargs)
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/deprecated/old_saveload.py&quot;, line 87, in load
#     obj = unpickle(fname)
#   File &quot;/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/deprecated/old_saveload.py&quot;, line 379, in unpickle
#     return _pickle.loads(file_bytes, encoding='latin1')
# _pickle.UnpicklingError: could not find MARK</textarea>
#   </form>
# </div>
# <div class="explanation">
#   The debugger caught an exception in your WSGI application.  You can now
#   look at the traceback which led to the error.  <span class="nojavascript">
#   If you enable JavaScript you can also use additional features such as code
#   execution (if the evalex feature is enabled), automatic pasting of the
#   exceptions and much more.</span>
# </div>
#       <div class="footer">
#         Brought to you by <strong class="arthur">DON'T PANIC</strong>, your
#         friendly Werkzeug powered traceback interpreter.
#       </div>
#     </div>
#
#     <div class="pin-prompt">
#       <div class="inner">
#         <h3>Console Locked</h3>
#         <p>
#           The console is locked and needs to be unlocked by entering the PIN.
#           You can find the PIN printed out on the standard output of your
#           shell that runs the server.
#         <form>
#           <p>PIN:
#             <input type=text name=pin size=14>
#             <input type=submit name=btn value="Confirm Pin">
#         </form>
#       </div>
#     </div>
#   </body>
# </html>
#
# <!--
#
# Traceback (most recent call last):
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2309, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2295, in wsgi_app
#     response = self.handle_exception(e)
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1741, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 35, in reraise
#     raise value
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 35, in reraise
#     raise value
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/dilyar/Downloads/opleiding_ki/tweedejaars_project/code/Vyno-Recommendation-Engine/api_call.py", line 102, in get_descriptors
#     embeddings = Word2Vec.load('models/wine_word2vec_model.bin')
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/word2vec.py", line 1152, in load
#     return load_old_word2vec(*args, **kwargs)
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/deprecated/word2vec.py", line 169, in load_old_word2vec
#     old_model = Word2Vec.load(*args, **kwargs)
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/deprecated/word2vec.py", line 1617, in load
#     model = super(Word2Vec, cls).load(*args, **kwargs)
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/deprecated/old_saveload.py", line 87, in load
#     obj = unpickle(fname)
#   File "/home/dilyar/anaconda3/lib/python3.7/site-packages/gensim/models/deprecated/old_saveload.py", line 379, in unpickle
#     return _pickle.loads(file_bytes, encoding='latin1')
# _pickle.UnpicklingError: could not find MARK
#
# -->
