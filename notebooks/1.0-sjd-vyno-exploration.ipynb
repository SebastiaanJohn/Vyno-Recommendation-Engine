# %%
import os
import pandas as pd
import numpy as np
import string
from operator import itemgetter
from collections import Counter, OrderedDict

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords

from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

# %% [markdown]
# ## Dataset

# %%
DATA = 'dataset/'

# preprocess wine dataset 1
cols = ['country', 'description', 'Wine name', 'province', 'Region', 'Sub region', 'Grape', 'Winery/ Vineyard']
wine_df1 = pd.read_csv(DATA + 'Vyno - Wine dataset 1.csv', dtype=str, usecols=cols)
wine_df1.columns = [title.lower() for title in wine_df1.columns]
wine_df1 = wine_df1.rename(columns={
    'wine name': 'wine_name',
    'sub region': 'sub_region', 
    'winery/ vineyard': 'vineyard'
})

# preprocess wine dataset 2
wine_df2 = pd.read_csv(DATA + 'Vyno - Wine dataset 2.csv', dtype=str).iloc[: , 1:]
wine_df2.columns = [title.lower() for title in wine_df2.columns]
wine_df2 = wine_df2.rename(columns={
    'wine name': 'wine_name',
    'sub region': 'sub_region', 
    'winery/ vineyard': 'vineyard'
})
cols2 = ['country', 'description', 'wine_name', 'province', 'region', 'sub_region', 'grape', 'vineyard', 'title']
wine_df2 = wine_df2[cols2]

# combine datasets into 1 dataframe
wine_df = pd.concat([wine_df1, wine_df2], axis=0)

# %%
wine_df = pd.read_csv('dataset/wine_dataset_all.csv', dtype=str).iloc[: , 1:]

# %%
wine_df.head(5)
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                               wine_name        province             region  \
# 0                     Martha's Vineyard      California        Napa Valley
# 1  Carodorum Selección Especial Reserva  Northern Spain               Toro
# 2         Special Selected Late Harvest      California     Knights Valley
# 3                               Reserve          Oregon  Willamette Valley
# 4                            La Brûlade        Provence             Bandol
#
#           sub_region               grape                 vineyard title
# 0               Napa  Cabernet Sauvignon                    Heitz   NaN
# 1                NaN       Tinta de Toro  Bodega Carmen Rodríguez   NaN
# 2             Sonoma     Sauvignon Blanc                 Macauley   NaN
# 3  Willamette Valley          Pinot Noir                    Ponzi   NaN
# 4                NaN  Provence red blend     Domaine de la Bégude   NaN

# %%
wine_df.shape
# Out:
# (280910, 9)

# %% [markdown]
# ## Wine descriptions

# %%
descriptions_list = list(wine_df['description'])
descriptions_list = [str(r) for r in descriptions_list]
full_corpus = ' '.join(descriptions_list)
sentences_tokenized = sent_tokenize(full_corpus)

print(sentences_tokenized[:5])
# Out:
# ['This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak.', 'Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background.', 'Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance.', 'Enjoy 2022–2030.', 'Ripe aromas of fig, blackberry and cassis are softened and sweetened by a slathering of oaky chocolate and vanilla.']

# %%
print(sentences_tokenized[0])
# Out:
# This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak.

# %%
stop_words = set(stopwords.words('english')) 

punctuation_table = str.maketrans({key: None for key in string.punctuation})
sno = SnowballStemmer('english')


def normalize_text(raw_text):
    try:
        word_list = word_tokenize(raw_text)
        normalized_sentence = []
        for w in word_list:
            try:
                w = str(w)
                lower_case_word = str.lower(w)
                stemmed_word = sno.stem(lower_case_word)
                no_punctuation = stemmed_word.translate(punctuation_table)
                if len(no_punctuation) > 1 and no_punctuation not in stop_words:
                    normalized_sentence.append(no_punctuation)
            except:
                continue
        return normalized_sentence
    except:
        return ''

normalized_sentences = []
for s in sentences_tokenized:
    normalized_text = normalize_text(s)
    normalized_sentences.append(normalized_text)

# %%
normalized_sentences[0:4]
# Out:
# [['tremend',
#   '100',
#   'variet',
#   'wine',
#   'hail',
#   'oakvill',
#   'age',
#   'three',
#   'year',
#   'oak'],
#  ['juici',
#   'redcherri',
#   'fruit',
#   'compel',
#   'hint',
#   'caramel',
#   'greet',
#   'palat',
#   'frame',
#   'eleg',
#   'fine',
#   'tannin',
#   'subtl',
#   'minti',
#   'tone',
#   'background'],
#  ['balanc', 'reward', 'start', 'finish', 'year', 'ahead', 'develop', 'nuanc'],
#  ['enjoy', '2022–2030']]

# %%
import itertools
test_sent = list(itertools.chain.from_iterable(normalized_sentences[0:4]))
print(test_sent)
# Out:
# ['tremend', '100', 'variet', 'wine', 'hail', 'oakvill', 'age', 'three', 'year', 'oak', 'juici', 'redcherri', 'fruit', 'compel', 'hint', 'caramel', 'greet', 'palat', 'frame', 'eleg', 'fine', 'tannin', 'subtl', 'minti', 'tone', 'background', 'balanc', 'reward', 'start', 'finish', 'year', 'ahead', 'develop', 'nuanc', 'enjoy', '2022–2030']

# %%
ngrams[test_sent]
# Out:
# ['tremend',
#  '100_variet',
#  'wine',
#  'hail',
#  'oakvill',
#  'age',
#  'three_year',
#  'oak',
#  'juici',
#  'redcherri',
#  'fruit',
#  'compel',
#  'hint',
#  'caramel',
#  'greet',
#  'palat',
#  'frame',
#  'eleg',
#  'fine',
#  'tannin',
#  'subtl',
#  'minti',
#  'tone',
#  'background',
#  'balanc',
#  'reward',
#  'start',
#  'finish',
#  'year',
#  'ahead',
#  'develop',
#  'nuanc',
#  'enjoy',
#  '2022–2030']

# %%
phrases = Phrases(normalized_sentences)
phrases = Phrases(phrases[normalized_sentences])

ngrams = Phraser(phrases)

phrased_sentences = []
for sent in normalized_sentences:
    phrased_sentence = ngrams[sent]
    phrased_sentences.append(phrased_sentence)

full_list_words = [item for sublist in phrased_sentences for item in sublist]

# %%
ngrams.save('ngrams')

# %%
phrased_sentences[0:4]
# Out:
# [['tremend',
#   '100_variet',
#   'wine',
#   'hail',
#   'oakvill',
#   'age',
#   'three_year',
#   'oak'],
#  ['juici',
#   'redcherri',
#   'fruit',
#   'compel',
#   'hint',
#   'caramel',
#   'greet',
#   'palat',
#   'frame',
#   'eleg',
#   'fine',
#   'tannin',
#   'subtl',
#   'minti',
#   'tone',
#   'background'],
#  ['balanc', 'reward', 'start', 'finish', 'year', 'ahead', 'develop', 'nuanc'],
#  ['enjoy', '2022–2030']]

# %%
word_counts = Counter(full_list_words)
sorted_counts = OrderedDict(word_counts.most_common(5000))
counter_df = pd.DataFrame.from_dict(sorted_counts, orient='index')
counter_df.to_csv('top_5000_descriptors.csv')

# %%
counter_df
# Out:
#                     0
# wine           177973
# flavor         156421
# fruit          127581
# finish          85879
# acid            79412
# ...               ...
# expos              60
# tenuta             60
# acrid              60
# previous_year      60
# chapin             60
#
# [5000 rows x 1 columns]

# %%
descriptor_mapping = pd.read_csv('descriptor_mapping.csv').set_index('raw descriptor')
descriptor_mapping.head(10)
# Out:
#                     level_3        level_2 level_1
# raw descriptor
# abras              abrasive    high_tannin  tannin
# acacia               acacia        flowery  flower
# acacia_flower        acacia        flowery  flower
# aciddriven      acid_driven      high_acid    acid
# aggress          aggressive      high_acid    acid
# airi                   airy   light_bodied    body
# allspic            allspice  baking_spices   spice
# almond               almond          nutty   nutty
# almond_past          almond          nutty   nutty
# marzipan             almond          nutty   nutty

# %%
def return_mapped_descriptor(word):
    if word in list(descriptor_mapping.index):
        normalized_word = descriptor_mapping['level_3'][word]
        return normalized_word
    else:
        return word

normalized_sentences = []
for sent in phrased_sentences:
    normalized_sentence = []
    for word in sent:
        normalized_word = return_mapped_descriptor(word)
        normalized_sentence.append(str(normalized_word))
    normalized_sentences.append(normalized_sentence)

# %%
normalized_sentences[0:4]
# Out:
# [['tremend',
#   '100',
#   'variet',
#   'wine',
#   'hail',
#   'oakvill',
#   'age',
#   'three',
#   'year',
#   'oak'],
#  ['juici',
#   'redcherri',
#   'fruit',
#   'compel',
#   'hint',
#   'caramel',
#   'greet',
#   'palat',
#   'frame',
#   'eleg',
#   'fine',
#   'tannin',
#   'subtl',
#   'minti',
#   'tone',
#   'background'],
#  ['balanc', 'reward', 'start', 'finish', 'year', 'ahead', 'develop', 'nuanc'],
#  ['enjoy', '2022–2030']]

# %%
# wine_word2vec_model = Word2Vec(normalized_sentences, vector_size=300, min_count=5, epochs=15)
# print(wine_word2vec_model)

# wine_word2vec_model.save('wine_word2vec_model.bin')
# Out:
# Word2Vec(vocab=25421, vector_size=300, alpha=0.025)

# %%
wine_word2vec_model = Word2Vec.load("wine_word2vec_model.bin")

# %%
wine_word2vec_model.wv.most_similar(positive='peach', topn=10)
# Out:
# [('peach_nectar', 0.6729379892349243),
#  ('pear', 0.6664803624153137),
#  ('honeydew', 0.6348575353622437),
#  ('grapefruit', 0.6208798289299011),
#  ('stone_fruit', 0.6191845536231995),
#  ('apple', 0.6178895831108093),
#  ('citrus', 0.6098344922065735),
#  ('lime', 0.6090511083602905),
#  ('kiwi', 0.6007109880447388),
#  ('lemon', 0.5999903082847595)]

# %% [markdown]
# ## From Word Embeddings to Wine Review Embeddings

# %%
wine_descriptions = list(wine_df['description'])

def return_descriptor_from_mapping(word):
    if word in list(descriptor_mapping.index):
        descriptor_to_return = descriptor_mapping['level_3'][word]
        return descriptor_to_return

descriptorized_descriptions = []
for desc in wine_descriptions:
    normalized_desc = normalize_text(desc)
    phrased_desc = ngrams[normalized_desc]
    descriptors_only = [return_descriptor_from_mapping(word) for word in phrased_desc]
    no_nones = [str(d) for d in descriptors_only if d is not None]
    descriptorized_desc = ' '.join(no_nones)
    descriptorized_descriptions.append(descriptorized_desc)

# %%
descriptorized_descriptions[0]
# Out:
# 'oak juicy cherry fruit caramel elegant mint'

# %%
len(dict_of_tfidf_weightings)
# Out:
# 600

# %%
X.get_feature_names()
# Out:
# ['abrasive',
#  'acacia',
#  'acid_driven',
#  'aggressive',
#  'aid',
#  'airy',
#  'allspice',
#  'almond',
#  'alpine_herbs',
#  'american_oak',
#  'angular',
#  'anise',
#  'apple',
#  'apple_sauce',
#  'apricot',
#  'ash',
#  'asian_spice',
#  'asparagus',
#  'asphalt',
#  'assertive',
#  'astringent',
#  'austere',
#  'bacon',
#  'baked',
#  'baked_bread',
#  'baking_spices',
#  'balsamic',
#  'banana',
#  'band',
#  'barbecue',
#  'bark',
#  'barnyard',
#  'basil',
#  'bay_leaf',
#  'beef',
#  'beef_jerky',
#  'beefy',
#  'beeswax',
#  'beet',
#  'beetroot',
#  'bell_pepper',
#  'bergamot',
#  'berry',
#  'big',
#  'bite',
#  'bitter',
#  'bitter_almond',
#  'bittersweet',
#  'black_cherry',
#  'black_fruit',
#  'black_pepper',
#  'blackberry',
#  'blackcurrant',
#  'bland',
#  'blood_orange',
#  'blossom',
#  'blue',
#  'blue_flower',
#  'blue_fruit',
#  'blueberry',
#  'bold',
#  'bone_dry',
#  'boned',
#  'botrytis',
#  'boysenberry',
#  'bramble',
#  'brawny',
#  'bread',
#  'bread_crust',
#  'brick',
#  'bright',
#  'brilliant',
#  'brine',
#  'brioche',
#  'brisk',
#  'brown',
#  'brown_butter',
#  'brown_sugar',
#  'bubble_gum',
#  'bubblegum',
#  'bulky',
#  'bullish',
#  'buoyant',
#  'burnt',
#  'butter',
#  'butter_nut',
#  'butter_popcorn',
#  'buttercream',
#  'butterscotch',
#  'buttery_toast',
#  'cake',
#  'campfire',
#  'camphor',
#  'candle_wax',
#  'candy',
#  'caramel',
#  'cardamom',
#  'carob',
#  'cashew',
#  'cassis',
#  'cataloupe',
#  'cedar',
#  'celery',
#  'cement',
#  'chalk',
#  'chamomile',
#  'charcoal',
#  'cheese',
#  'chemical',
#  'cherry',
#  'chewi',
#  'chocolate',
#  'choppy',
#  'chunky',
#  'cider',
#  'cigar',
#  'cigar_box',
#  'cinnamon',
#  'citrus',
#  'citrus_peel',
#  'citrus_pith',
#  'clampy',
#  'classy',
#  'clay',
#  'clean',
#  'close',
#  'closed',
#  'clove',
#  'cloying',
#  'coarse',
#  'cocoa',
#  'coconut',
#  'coffee',
#  'cola',
#  'complex',
#  'complicated',
#  'compost',
#  'compote',
#  'concentrated',
#  'concrete',
#  'cooked',
#  'cookie',
#  'corn',
#  'cotton_candy',
#  'cracker',
#  'cranberry',
#  'cranberry_pomegranate',
#  'cream',
#  'creamy',
#  'crisp',
#  'crunchy',
#  'cucumber',
#  'cured_meat',
#  'currant',
#  'custard',
#  'cut_grass',
#  'dainty',
#  'dark',
#  'dark_berry',
#  'dark_fruit',
#  'dense',
#  'depth',
#  'diesel',
#  'dill',
#  'diluted',
#  'dr_pepper',
#  'driven',
#  'dry',
#  'dull',
#  'dust',
#  'earth',
#  'earthy',
#  'easy',
#  'edgy',
#  'effervescent',
#  'elderberry',
#  'elderflower',
#  'elegant',
#  'espresso',
#  'eucalyptus',
#  'expansive',
#  'extracted',
#  'exuberant',
#  'fat',
#  'feminine',
#  'fennel',
#  'feral',
#  'fig',
#  'finegrained_tannin',
#  'finessed',
#  'firm',
#  'fizz',
#  'flabby',
#  'flashy',
#  'flat',
#  'fleshy',
#  'flint',
#  'flower',
#  'foamy',
#  'forest_floor',
#  'forward',
#  'foxy',
#  'french_oak',
#  'fresh',
#  'frothy',
#  'fruit',
#  'fruity',
#  'fudge',
#  'full_bodied',
#  'funky',
#  'game',
#  'ginger',
#  'gingerbread',
#  'gold',
#  'gooseberry',
#  'grabby',
#  'graham_cracker',
#  'grain',
#  'grained_tannin',
#  'grainy',
#  'granite',
#  'grapefruit',
#  'grapefruit_peel',
#  'grapefruit_pith',
#  'grapey',
#  'graphite',
#  'grass',
#  'gravel',
#  'green',
#  'green_bean',
#  'green_fruit',
#  'green_pepper',
#  'grilled_herbs',
#  'grilled_meat',
#  'gripping',
#  'grippy',
#  'gritty',
#  'guava',
#  'gummy',
#  'ham',
#  'hard',
#  'hay',
#  'hazelnut',
#  'heady',
#  'hearty',
#  'heavy',
#  'herb',
#  'herbacious',
#  'herbs',
#  'hibiscus',
#  'hickory',
#  'hickory_smoke',
#  'high_acid',
#  'high_alcohol',
#  'hollow',
#  'honey',
#  'honeycomb',
#  'honeydew',
#  'honeysuckle',
#  'horsey',
#  'hot',
#  'huckleberry',
#  'incense',
#  'indian_spice',
#  'inky',
#  'iodine',
#  'iron',
#  'jagged',
#  'jam',
#  'jasmine',
#  'jelly',
#  'juicy',
#  'juniper',
#  'kirsch',
#  'kiwi',
#  'kumquat',
#  'lactic',
#  'lanolin',
#  'latex',
#  'lavender',
#  'lavish',
#  'leafy',
#  'lean',
#  'leather',
#  'lees',
#  'lemon',
#  'lemon_curd',
#  'lemon_custard',
#  'lemon_drop',
#  'lemon_meringue',
#  'lemon_peel',
#  'lemon_pith',
#  'lemon_verbena',
#  'lemongrass',
#  'length',
#  'lengthy',
#  'lettuce',
#  'licorice',
#  'light',
#  'light_bodied',
#  'light_color',
#  'lilac',
#  'lime',
#  'lime_peel',
#  'lime_pith',
#  'limestone',
#  'linear',
#  'loamy',
#  'low_alcohol',
#  'low_complexity',
#  'luminous',
#  'lush',
#  'luxurious',
#  'lychee',
#  'mace',
#  'mandarin',
#  'mango',
#  'maple',
#  'maple_syrup',
#  'marjoram',
#  'marmalade',
#  'marshmallow',
#  'masculine',
#  'mass',
#  'matchstick',
#  'mealy',
#  'meat',
#  'meaty',
#  'medicinal',
#  'meditteranean_herbs',
#  'medium_bodied',
#  'medium_length_finish',
#  'medium_sweet',
#  'mellow',
#  'melon',
#  'melon_rind',
#  'melted_butter',
#  'menthol',
#  'metal',
#  'milk_chocolate',
#  'mineral',
#  'minerality',
#  'mint',
#  'modest',
#  'moist_earth',
#  'molasses',
#  'moss',
#  'mousse',
#  'mulberry',
#  'mulch',
#  'murky',
#  'muscular',
#  'mushroom',
#  'musky',
#  'mustard',
#  'nectar',
#  'nectarine',
#  'nervy',
#  'nettle',
#  'nut',
#  'nutmeg',
#  'oak',
#  'oaked',
#  'ocean',
#  'off',
#  'oil',
#  'oily',
#  'olallieberry',
#  'olive',
#  'one_dimensional',
#  'opulent',
#  'orange',
#  'orange_blossom',
#  'orange_marmalade',
#  'orange_peel',
#  'oregano',
#  'over',
#  'overripe',
#  'oxidized',
#  'pale',
#  'pale_color',
#  'papaya',
#  'passion_fruit',
#  'pastry',
#  'pea',
#  'peach',
#  'peach_pit',
#  'peanut',
#  'pear',
#  'pencil_lead',
#  'pencil_shaving',
#  'pepper',
#  'perfumed',
#  'persimmon',
#  'petal',
#  'petrol',
#  'phenolic',
#  'pickled',
#  'pie',
#  'piercing',
#  'pillowy',
#  'pine',
#  'pineapple',
#  'pink',
#  'pink_color',
#  'pith',
#  'plastic',
#  'plum',
#  'plump',
#  'plush',
#  'polished',
#  'pollen',
#  'pomegranate',
#  'pop',
#  'popcorn',
#  'potpourri',
#  'powdery',
#  'powerful',
#  'prickly',
#  'prune',
#  'prune_raisin',
#  'puckery',
#  'pulpy',
#  'punchy',
#  'pungent',
#  'purple',
#  'purple_flower',
#  'pyrazines',
#  'quaffer',
#  'quince',
#  'racy',
#  'raisin',
#  'raisin_prune',
#  'raspberry',
#  'raspy',
#  'red_berry',
#  'red_currant',
#  'red_fruit',
#  'red_plum',
#  'reductive',
#  'reedy',
#  'refined',
#  'refreshing',
#  'residual_sugar',
#  'resin',
#  'restrained',
#  'rhubarb',
#  'rich',
#  'rind',
#  'ripe',
#  'roast_beef',
#  'roasted_almond',
#  'roasted_meat',
#  'robust',
#  'rocks',
#  'rocky',
#  'root',
#  'rose',
#  'rose_violet',
#  'rosemary',
#  'rosewater',
#  'rough',
#  'round',
#  'rubber',
#  'ruby_color',
#  'rum_cake',
#  'rustic',
#  'rusty',
#  'saddle_leather',
#  'saffron',
#  'sage',
#  'saline',
#  'salt',
#  'sandalwood',
#  'sanguine',
#  'sappy',
#  'sassafras',
#  'satiny',
#  'savory',
#  'sawdust',
#  'scorched_earth',
#  'scratchy',
#  'semisweet',
#  'sharp',
#  'shimmer',
#  'shine',
#  'shoe_polish',
#  'silky',
#  'simple',
#  'sinewy',
#  'sizzling',
#  'slate',
#  'sleek',
#  'slick',
#  'smoke',
#  'smoked_bacon',
#  'smoked_meat',
#  'smoked_nut',
#  'smooth',
#  'snappy',
#  'soapy',
#  'soft',
#  'soil',
#  'sorbet',
#  'sour',
#  'soy',
#  'soy_sauce',
#  'sparkling',
#  'spearmint',
#  'spice',
#  'spiky',
#  'spring_flower',
#  'spritzy',
#  'stalky',
#  'star_anise',
#  'steak',
#  'steel',
#  'stemmy',
#  'stewed_prune',
#  'sticky',
#  'stone',
#  'stone_fruit',
#  'stout',
#  'straw',
#  'strawberry',
#  'struck_flint',
#  'sturdy',
#  'succulent',
#  'sugar',
#  'sulfur',
#  'super_rich',
#  'super_ripe',
#  'supple',
#  'sweat',
#  'sweet',
#  'syrupy',
#  'tangerine',
#  'tangerine_peel',
#  'tangy',
#  'tannin',
#  'tar',
#  'tarragon',
#  'tart',
#  'tea',
#  'thick',
#  'thyme',
#  'tight',
#  'tingling',
#  'tingly',
#  'tire_rubber',
#  'toast',
#  'toasted_almond',
#  'toasted_hazelnut',
#  'toasted_nut',
#  'tobacco',
#  'toffee',
#  'tomato',
#  'tree_bark',
#  'tropical_fruit',
#  'truffle',
#  'umami',
#  'undergrowth',
#  'underripe',
#  'unoaked',
#  'unripe',
#  'vanilla',
#  'vanilla_cream',
#  'vegetal',
#  'velvety',
#  'vibrant',
#  'vinegar',
#  'violet',
#  'violet_rose',
#  'viscous',
#  'voluptuous',
#  'walnut',
#  'warm',
#  'watermelon',
#  'watery',
#  'wax',
#  'weed',
#  'weight',
#  'wet_clay',
#  'wet_earth',
#  'wet_rocks',
#  'white',
#  'white_flower',
#  'white_fruit',
#  'wild_berry',
#  'wildflower',
#  'wood',
#  'wood_spice',
#  'woody_berry',
#  'yeast',
#  'yellow',
#  'yellow_fruit',
#  'zest',
#  'zesty',
#  'zingy',
#  'zippy']

# %%
import pickle
pickle.dump(X, open("vectorizer.pickle", "wb"))

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit(descriptorized_descriptions)

dict_of_tfidf_weightings = dict(zip(X.get_feature_names(), X.idf_))

wine_description_vectors = []
for d in descriptorized_descriptions:
    descriptor_count = 0
    weighted_description_terms = []
    terms = d.split(' ')
    for term in terms:
        if term in dict_of_tfidf_weightings.keys():
            tfidf_weighting = dict_of_tfidf_weightings[term]
            word_vector = wine_word2vec_model.wv.get_vector(term).reshape(1, 300)
            weighted_word_vector = tfidf_weighting * word_vector
            weighted_description_terms.append(weighted_word_vector)
            descriptor_count += 1
        else:
            continue
    try:
        description_vector = sum(weighted_description_terms)/len(weighted_description_terms)
    except:
        description_vector = []
    vector_and_count = [terms, description_vector, descriptor_count]
    wine_description_vectors.append(vector_and_count)

wine_df['normalized_descriptors'] = list(map(itemgetter(0), wine_description_vectors))
wine_df['description_vector'] = list(map(itemgetter(1), wine_description_vectors))
wine_df['descriptor_count'] = list(map(itemgetter(2), wine_description_vectors))

wine_df.reset_index(inplace=True)
wine_df.head()
# Out:
#    index country                                        description  \
# 0      0      US  This tremendous 100% varietal wine hails from ...
# 1      1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      2      US  Mac Watson honors the memory of a wine once ma...
# 3      3      US  This spent 20 months in 30% new French oak, an...
# 4      4  France  This is the top wine from La Bégude, named aft...
#
#                               wine_name        province             region  \
# 0                     Martha's Vineyard      California        Napa Valley
# 1  Carodorum Selección Especial Reserva  Northern Spain               Toro
# 2         Special Selected Late Harvest      California     Knights Valley
# 3                               Reserve          Oregon  Willamette Valley
# 4                            La Brûlade        Provence             Bandol
#
#           sub_region               grape                 vineyard title  \
# 0               Napa  Cabernet Sauvignon                    Heitz   NaN
# 1                NaN       Tinta de Toro  Bodega Carmen Rodríguez   NaN
# 2             Sonoma     Sauvignon Blanc                 Macauley   NaN
# 3  Willamette Valley          Pinot Noir                    Ponzi   NaN
# 4                NaN  Provence red blend     Domaine de la Bégude   NaN
#
#                               normalized_descriptors  \
# 0  [oak, juicy, cherry, fruit, caramel, elegant, ...
# 1  [ripe, fig, blackberry, cassis, oak, chocolate...
# 2  [complex, white, dark, gold, toasted_hazelnut,...
# 3  [oak, fruit, dense, toast, toast, cigar_box, b...
# 4                  [dense, wood, rich, concentrated]
#
#                                   description_vector  descriptor_count
# 0  [[-2.0711305, -4.7418947, -2.138353, -0.596845...                 7
# 1  [[-1.8445625, -5.050164, -4.2829804, 0.1221863...                14
# 2  [[-2.3649457, -4.712655, -3.1457627, 0.8866671...                10
# 3  [[-1.6315883, -5.0111055, -3.8726304, -2.18882...                14
# 4  [[0.7936336, -5.4881744, 1.7294126, 2.6966877,...                 4

# %%
wine_df.to_csv('wine_df_descriptors_3.csv')

# %%
type(wine_df['description_vector'][0])
# Out:
# numpy.ndarray

# %%
wine_df.to_pickle("./wine_df.pkl")

# %%
wine_reviews_mincount = wine_df.loc[wine_df['descriptor_count'] > 8]

# %%
wine_reviews_mincount
# Out:
#          index  country                                        description  \
# 1            1    Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2            2       US  Mac Watson honors the memory of a wine once ma...
# 3            3       US  This spent 20 months in 30% new French oak, an...
# 5            5    Spain  Deep, dense and pure from the opening bell, th...
# 7            7    Spain  Lush cedary black-fruit aromas are luxe and of...
# ...        ...      ...                                                ...
# 280900  280900    Italy  Intense aromas of wild cherry, baking spice, t...
# 280901  280901    Italy  Blackberry, cassis, grilled herb and toasted a...
# 280902  280902   Israel  A bouquet of black cherry, tart cranberry and ...
# 280904  280904   France  While it's rich, this beautiful dry wine also ...
# 280905  280905  Germany  Notes of honeysuckle and cantaloupe sweeten th...
#
#                                      wine_name           province  \
# 1         Carodorum Selección Especial Reserva     Northern Spain
# 2                Special Selected Late Harvest         California
# 3                                      Reserve             Oregon
# 5                                    Numanthia     Northern Spain
# 7                      Carodorum Único Crianza     Northern Spain
# ...                                        ...                ...
# 280900                                     NaN  Sicily & Sardinia
# 280901               Sàgana Tenuta San Giacomo  Sicily & Sardinia
# 280902                                Oak Aged            Galilee
# 280904             Seppi Landmann Vallée Noble             Alsace
# 280905  Brauneberger Juffer-Sonnenuhr Spätlese              Mosel
#
#                    region         sub_region               grape  \
# 1                    Toro                NaN       Tinta de Toro
# 2          Knights Valley             Sonoma     Sauvignon Blanc
# 3       Willamette Valley  Willamette Valley          Pinot Noir
# 5                    Toro                NaN       Tinta de Toro
# 7                    Toro                NaN       Tinta de Toro
# ...                   ...                ...                 ...
# 280900            Sicilia                NaN            Frappato
# 280901            Sicilia                NaN        Nero d'Avola
# 280902                NaN                NaN  Cabernet Sauvignon
# 280904             Alsace                NaN          Pinot Gris
# 280905                NaN                NaN            Riesling
#
#                                         vineyard  \
# 1                        Bodega Carmen Rodríguez
# 2                                       Macauley
# 3                                          Ponzi
# 5                                      Numanthia
# 7                        Bodega Carmen Rodríguez
# ...                                          ...
# 280900                                       COS
# 280901                                  Cusumano
# 280902                                    Dalton
# 280904                   Domaine Rieflé-Landmann
# 280905  Dr. H. Thanisch (Erben Müller-Burggraef)
#
#                                                     title  \
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 5                                                     NaN
# 7                                                     NaN
# ...                                                   ...
# 280900                        COS 2013 Frappato (Sicilia)
# 280901  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...
# 280902  Dalton 2012 Oak Aged Cabernet Sauvignon (Galilee)
# 280904  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...
# 280905  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...
#
#                                    normalized_descriptors  \
# 1       [ripe, fig, blackberry, cassis, oak, chocolate...
# 2       [complex, white, dark, gold, toasted_hazelnut,...
# 3       [oak, fruit, dense, toast, toast, cigar_box, b...
# 5       [depth, dense, dark, ripe, fruit, oak, blackbe...
# 7       [lush, cedar, black_fruit, almond, vanilla, ta...
# ...                                                   ...
# 280900  [cherry, baked, spice, savory, herb, silky, ro...
# 280901  [blackberry, cassis, grilled_herbs, toast, cof...
# 280902  [flower, cherry, tart, cranberry, clove, cherr...
# 280904  [rich, dry, fresh, ripe, white, fruit, pear, a...
# 280905  [honeysuckle, cataloupe, sweet, juicy, tart, t...
#
#                                        description_vector  descriptor_count
# 1       [[-1.8445625, -5.050164, -4.2829804, 0.1221863...                14
# 2       [[-2.3649457, -4.712655, -3.1457627, 0.8866671...                10
# 3       [[-1.6315883, -5.0111055, -3.8726304, -2.18882...                14
# 5       [[-0.91695696, -4.525911, -2.2801418, -0.40843...                14
# 7       [[-2.334717, -5.676419, -3.870332, -2.1135352,...                14
# ...                                                   ...               ...
# 280900  [[-0.29395303, -4.318718, -2.8238916, -0.30541...                18
# 280901  [[-1.1284274, -5.352018, -6.0093055, -1.208133...                10
# 280902  [[-0.9823631, -5.9883256, -4.2795463, -2.35708...                16
# 280904  [[-0.9369676, -4.214651, -1.8300135, 1.3751801...                 9
# 280905  [[-2.0164046, -3.3920963, -3.2081838, -0.17288...                 9
#
# [124609 rows x 13 columns]

# %% [markdown]
# ## Recommender

# %%
# first, let's eliminate any review with fewer than 5 descriptors from our dataset
wine_reviews_mincount = wine_df.loc[wine_df['descriptor_count'] > 5]
wine_reviews_mincount.reset_index(inplace=True)

input_vectors = list(wine_reviews_mincount['description_vector'])
input_vectors_listed = [a.tolist() for a in input_vectors]
input_vectors_listed = [a[0] for a in input_vectors_listed]

knn = NearestNeighbors(n_neighbors=10, algorithm= 'brute', metric='cosine')
model_knn = knn.fit(input_vectors_listed)

# %%
input_vectors_listed[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-ecf4fb66e872> in <module>
# ----> 1 input_vectors_listed[0]
#
# NameError: name 'input_vectors_listed' is not defined

# %%
wine_reviews_mincount
# Out:
#         level_0   index  country  \
# 0             0       0       US
# 1             1       1    Spain
# 2             2       2       US
# 3             3       3       US
# 4             5       5    Spain
# ...         ...     ...      ...
# 234940   280904  129969   France
# 234941   280905  129970  Germany
# 234942   280906  129971       US
# 234943   280908  129973   France
# 234944   280909  129974   France
#
#                                               description  \
# 0       This tremendous 100% varietal wine hails from ...
# 1       Ripe aromas of fig, blackberry and cassis are ...
# 2       Mac Watson honors the memory of a wine once ma...
# 3       This spent 20 months in 30% new French oak, an...
# 4       Deep, dense and pure from the opening bell, th...
# ...                                                   ...
# 234940  While it's rich, this beautiful dry wine also ...
# 234941  Notes of honeysuckle and cantaloupe sweeten th...
# 234942  Citation is given as much as a decade of bottl...
# 234943  A dry style of Pinot Gris, this is crisp with ...
# 234944  Big, rich and off-dry, this is powered by inte...
#
#                                      wine_name        province  \
# 0                            Martha's Vineyard      California
# 1         Carodorum Selección Especial Reserva  Northern Spain
# 2                Special Selected Late Harvest      California
# 3                                      Reserve          Oregon
# 4                                    Numanthia  Northern Spain
# ...                                        ...             ...
# 234940             Seppi Landmann Vallée Noble          Alsace
# 234941  Brauneberger Juffer-Sonnenuhr Spätlese           Mosel
# 234942                                     NaN          Oregon
# 234943                                     NaN          Alsace
# 234944           Lieu-dit Harth Cuvée Caroline          Alsace
#
#                    region         sub_region               grape  \
# 0             Napa Valley               Napa  Cabernet Sauvignon
# 1                    Toro                NaN       Tinta de Toro
# 2          Knights Valley             Sonoma     Sauvignon Blanc
# 3       Willamette Valley  Willamette Valley          Pinot Noir
# 4                    Toro                NaN       Tinta de Toro
# ...                   ...                ...                 ...
# 234940             Alsace                NaN          Pinot Gris
# 234941                NaN                NaN            Riesling
# 234942             Oregon       Oregon Other          Pinot Noir
# 234943             Alsace                NaN          Pinot Gris
# 234944             Alsace                NaN      Gewürztraminer
#
#                                         vineyard  \
# 0                                          Heitz
# 1                        Bodega Carmen Rodríguez
# 2                                       Macauley
# 3                                          Ponzi
# 4                                      Numanthia
# ...                                          ...
# 234940                   Domaine Rieflé-Landmann
# 234941  Dr. H. Thanisch (Erben Müller-Burggraef)
# 234942                                  Citation
# 234943                      Domaine Marcel Deiss
# 234944                          Domaine Schoffit
#
#                                                     title  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 234940  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...
# 234941  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...
# 234942                  Citation 2004 Pinot Noir (Oregon)
# 234943      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 234944  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
#                                    normalized_descriptors  \
# 0       [oak, juicy, cherry, fruit, caramel, elegant, ...
# 1       [ripe, fig, blackberry, cassis, oak, chocolate...
# 2       [complex, white, dark, gold, toasted_hazelnut,...
# 3       [oak, fruit, dense, toast, toast, cigar_box, b...
# 4       [depth, dense, dark, ripe, fruit, oak, blackbe...
# ...                                                   ...
# 234940  [rich, dry, fresh, ripe, white, fruit, pear, a...
# 234941  [honeysuckle, cataloupe, sweet, juicy, tart, t...
# 234942  [baked, cherry, cocoa, coconut, soft, fruit, c...
# 234943  [dry, crisp, weight, powerful, spice, baked, a...
# 234944  [rich, off-dry, powerful, spice, round, lychee...
#
#                                        description_vector  descriptor_count
# 0       [[-2.0711305, -4.7418947, -2.138353, -0.596845...                 7
# 1       [[-1.8445625, -5.050164, -4.2829804, 0.1221863...                14
# 2       [[-2.3649457, -4.712655, -3.1457627, 0.8866671...                10
# 3       [[-1.6315883, -5.0111055, -3.8726304, -2.18882...                14
# 4       [[-0.91695696, -4.525911, -2.2801418, -0.40843...                14
# ...                                                   ...               ...
# 234940  [[-0.9369676, -4.214651, -1.8300135, 1.3751801...                 9
# 234941  [[-2.0164046, -3.3920963, -3.2081838, -0.17288...                 9
# 234942  [[-3.085924, -5.2862296, -2.7884707, 0.3871322...                 7
# 234943  [[-1.3344327, -2.0043838, -1.1969368, 0.530952...                 7
# 234944  [[0.07041918, -2.7727451, -2.1272438, 0.811379...                 7
#
# [234945 rows x 14 columns]

# %%
name_test = "Seppi Landmann Vallée Noble"

wine_test_vector = wine_reviews_mincount.loc[wine_reviews_mincount['wine_name'] == name_test]['description_vector'].tolist()[0]
distance, indice = model_knn.kneighbors(wine_test_vector, n_neighbors=9)
distance_list = distance[0].tolist()[1:]
indice_list = indice[0].tolist()[1:]

main_wine = wine_reviews_mincount.loc[wine_reviews_mincount['wine_name'] == name_test]

print('Wine to match:', name_test)
print('The original wine has the following descriptors:', list(main_wine['normalized_descriptors'])[0])
print('_________')

n = 1
for d, i in zip(distance_list, indice_list):
    wine_name = wine_reviews_mincount['wine_name'][i]
    wine_descriptors = wine_reviews_mincount['normalized_descriptors'][i]
    print('Suggestion', str(n), ':', wine_name, 'with a cosine distance of', "{:.3f}".format(d))
    print('This wine has the following descriptors:', wine_descriptors)
    print('')
    n+=1
# Out:
# Wine to match: Seppi Landmann Vallée Noble
# The original wine has the following descriptors: ['ripe', 'powerful', 'rich', 'perfumed', 'white', 'fruit', 'flower', 'minerality']
# _________
# Suggestion 1 : Seppi Landmann Vallée Noble with a cosine distance of 0.000
# This wine has the following descriptors: ['ripe', 'powerful', 'rich', 'perfumed', 'white', 'fruit', 'flower', 'minerality']
#
# Suggestion 2 : Katharinas Reserve with a cosine distance of 0.052
# This wine has the following descriptors: ['perfumed', 'rich', 'minerality', 'white', 'fruit', 'fruit']
#
# Suggestion 3 : Marquis de Laguiche Morgeot Premier Cru with a cosine distance of 0.080
# This wine has the following descriptors: ['perfumed', 'flower', 'weight', 'rich', 'concentrated', 'rich', 'yellow', 'white', 'fruit', 'minerality']
#
# Suggestion 4 : Barrel sample with a cosine distance of 0.080
# This wine has the following descriptors: ['powerful', 'perfumed', 'fruit', 'rich', 'fruit', 'minerality']
#
# Suggestion 5 : Barrel sample with a cosine distance of 0.080
# This wine has the following descriptors: ['powerful', 'perfumed', 'fruit', 'rich', 'fruit', 'minerality']
#
# Suggestion 6 : Barrel sample with a cosine distance of 0.080
# This wine has the following descriptors: ['powerful', 'perfumed', 'fruit', 'rich', 'fruit', 'minerality']
#
# Suggestion 7 : Cuvée des Conti with a cosine distance of 0.086
# This wine has the following descriptors: ['ripe', 'rich', 'perfumed', 'fruit', 'flower', 'fruit', 'citrus']
#
# Suggestion 8 : Cuvée des Conti with a cosine distance of 0.086
# This wine has the following descriptors: ['ripe', 'rich', 'perfumed', 'fruit', 'flower', 'fruit', 'citrus']

# %%
# Out:
# zsh:1: command not found: pandas
